# %%
import torch
a=torch.tensor([2,3,4,5])
print("a:", a)
b=torch.tensor([5,4,3,2])
print("b:", b)
c=a+b
print("c:", c)
d=a-b
print("d:", d)
e=a*b
print("e;", e)
# Out:
# a: tensor([2, 3, 4, 5])
# b: tensor([5, 4, 3, 2])
# c: tensor([7, 7, 7, 7])
# d: tensor([-3, -1,  1,  3])
# e; tensor([10, 12, 12, 10])
