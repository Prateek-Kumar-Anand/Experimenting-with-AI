# %%
#Checking for cuda
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
#Creating a named tensor
img_t=torch.randn(3,5,5)
img_t
# Out:
# tensor([[[-0.6815, -0.6264, -0.1778,  1.2591,  0.0196],
#          [-2.0310, -1.5054,  0.5409, -0.4440, -0.5140],
#          [ 0.3602,  0.3438, -1.5633,  1.1153, -1.3286],
#          [-0.1402,  0.5878,  0.9478,  0.7002,  0.2577],
#          [ 0.6193,  0.4084,  0.6841, -0.2725,  0.5214]],
#
#         [[ 1.0839, -0.2508, -0.3657,  0.6952,  1.3365],
#          [-1.2259,  1.1968,  0.2097,  0.4609,  1.2162],
#          [-0.2836, -0.4709,  1.4683, -1.8545, -0.4732],
#          [-0.4013,  0.2860, -0.8624,  1.0205,  0.7789],
#          [-0.4508,  0.9105, -0.6947, -0.0757,  0.0353]],
#
#         [[-0.2610,  1.2294,  0.7055,  0.1823,  0.6329],
#          [ 0.7449, -0.7078,  0.0692,  1.4838, -1.1633],
#          [ 0.5001,  0.2700, -0.1604,  0.2960,  1.6062],
#          [-0.9907,  0.0719,  0.2245, -0.3973,  0.8198],
#          [-0.7295, -0.2111, -0.6518,  1.5708, -0.0681]]])

# %%
#Creating another named tensor
matrix=torch.randn(2,1,2)
matrix
# Out:
# tensor([[[-0.3503, -0.4595]],
#
#         [[-1.0671,  0.7689]]])

# %%
#This shows torch.randn does not always give same tensor
#torch.randn(a,b,c)----torch.rand(chanels,rows,column)
subject=torch.randn(2,4,1)
print('subject:', subject)
testsubject=torch.randn(2,4,1)
print('testsubject:', testsubject)
# Out:
# subject: tensor([[[ 0.4302],
#          [-1.5372],
#          [-0.1059],
#          [ 1.3799]],
#
#         [[-0.8339],
#          [ 0.4921],
#          [ 0.5241],
#          [ 1.6559]]])
# testsubject: tensor([[[-1.1972],
#          [ 1.5039],
#          [ 0.0933],
#          [-0.3283]],
#
#         [[-0.5928],
#          [-0.6564],
#          [-1.4731],
#          [-1.1490]]])

# %%
#creating a tensor with a batch
#torch.randn(a,b,c,d)--torch.randn(batch,chanel,row,column)
a=torch.randn(1,2,2,1)
print('a', a)
# Out:
# a tensor([[[[ 0.4109],
#           [ 0.5129]],
#
#          [[-0.2289],
#           [-0.4541]]]])
